# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
import configparser
from os import path
import pandas as pd
import matplotlib.gridspec as gridspec
import io_util as iot
import locale
from matplotlib.offsetbox import AnchoredOffsetbox, TextArea, DrawingArea, HPacker
from cycler import cycler
import matplotlib.path as mpath
import mri_draw_utils as mrd
import math_format as mf
import matplotlib.ticker as ticker
from matplotlib.ticker import ScalarFormatter
from matplotlib.ticker import LogFormatterSciNotation
import io_util
from math import sqrt
from mpl_toolkits.mplot3d import Axes3D

# %%
data_path = "/work/pl/sch/analysis/my_paper/analysis/results/structural/multirun/results/avg_solution_cost_combined_all.csv"

# %%
data = iot.read_data_structural(data_path)

# %%
subset4D = data.loc[data['tensor_dim'] == 4]

# %%
subset4D
# Out:
#     tensor_dim    k  observed_ratio  mr  ts_count  el_volume  roi_volume  \
# 0            4  115            0.95   5         7  2345.7224       16420
# 1            4  110            0.95   5         7  2680.8257       18765
# 2            4  131            0.95   5         7  3015.9290       21111
# 3            4  100            0.95   5         7  3351.0322       23457
# 4            4   62            0.95   5         7  3686.1355       25802
# 5            4  110            0.95   5         7  4021.2385       28148
# 6            4  139            0.90  10        14  2345.7224       32840
# 7            4  105            0.90  10        14  2680.8257       37531
# 8            4  121            0.90  10        14  3015.9290       42223
# 9            4   68            0.90  10        14  3351.0322       46914
# 10           4   88            0.90  10        14  3686.1355       51605
# 11           4  116            0.90  10        14  4021.2385       56297
# 12           4  108            0.85  15        21  2345.7224       49260
# 13           4   93            0.85  15        21  2680.8257       56297
# 14           4  117            0.85  15        21  3015.9290       63334
# 15           4   67            0.85  15        21  3351.0322       70371
# 16           4   87            0.85  15        21  3686.1355       77408
# 17           4   37            0.85  15        21  4021.2385       84446
# 18           4   47            0.80  20        28  2345.7224       65680
# 19           4   54            0.80  20        28  2680.8257       75063
# 20           4   67            0.80  20        28  3015.9290       84446
# 21           4   44            0.80  20        28  3351.0322       93828
# 22           4   33            0.80  20        28  3686.1355      103211
# 23           4   56            0.80  20        28  4021.2385      112594
# 24           4   36            0.75  25        36  2345.7224       84446
# 25           4   40            0.75  25        36  2680.8257       96509
# 26           4   33            0.75  25        36  3015.9290      108573
# 27           4   78            0.75  25        36  3351.0322      120637
# 28           4   54            0.75  25        36  3686.1355      132700
# 29           4   30            0.75  25        36  4021.2385      144764
#
#     tcs_cost roi_volume_label  tsc_z_cost             ...               \
# 0   0.002607            size0    0.002346             ...
# 1   0.002822            size1    0.002787             ...
# 2   0.002803            size2    0.002968             ...
# 3   0.003107            size3    0.003701             ...
# 4   0.003402            size4    0.004162             ...
# 5   0.003530            size5    0.004350             ...
# 6   0.003225            size0    0.002483             ...
# 7   0.003796            size1    0.003586             ...
# 8   0.006370            size2    0.009403             ...
# 9   0.007026            size3    0.012854             ...
# 10  0.007320            size4    0.012576             ...
# 11  0.007392            size5    0.012906             ...
# 12  0.003566            size0    0.002948             ...
# 13  0.004169            size1    0.003927             ...
# 14  0.009005            size2    0.014617             ...
# 15  0.011545            size3    0.017190             ...
# 16  0.014413            size4    0.019233             ...
# 17  0.024716            size5    0.044378             ...
# 18  0.038979            size0    0.021249             ...
# 19  0.032003            size1    0.021130             ...
# 20  0.046392            size2    0.033604             ...
# 21  0.092458            size3    0.104045             ...
# 22  0.085953            size4    0.072436             ...
# 23  0.271908            size5    0.267654             ...
# 24  0.056037            size0    0.032164             ...
# 25  0.104205            size1    0.108126             ...
# 26  0.096182            size2    0.069717             ...
# 27  0.174030            size3    0.231210             ...
# 28  0.481524            size4    0.453043             ...
# 29  0.357968            size5    0.425758             ...
#
#     train_cost  solution_cost  \
# 0     0.003639       0.000004
# 1     0.003652       0.000004
# 2     0.003639       0.000004
# 3     0.003638       0.000004
# 4     0.003638       0.000004
# 5     0.003638       0.000004
# 6     0.003639       0.000004
# 7     0.003640       0.000004
# 8     0.003640       0.000004
# 9     0.003626       0.000004
# 10    0.003626       0.000004
# 11    0.005439       0.000006
# 12    0.001456       0.000002
# 13    0.003639       0.000004
# 14    0.003640       0.000004
# 15    0.003642       0.000004
# 16    0.005095       0.000005
# 17    0.003643       0.000004
# 18    0.003646       0.000004
# 19    0.007645       0.000008
# 20    0.003644       0.000004
# 21    0.003648       0.000004
# 22    0.003654       0.000004
# 23    0.003677       0.000004
# 24    0.003649       0.000004
# 25    0.003652       0.000004
# 26    0.003657       0.000004
# 27    0.003671       0.000004
# 28    0.003677       0.000004
# 29    0.003681       0.000004
#
#                                      image_final_path  \
# 0   /home/ec2-user/analysis/work/scratch/tensor_co...
# 1   /work/scratch/tensor_completion/4D/structural/...
# 2   /home/ec2-user/analysis/work/scratch/tensor_co...
# 3   /home/ec2-user/analysis/work/scratch/tensor_co...
# 4   /home/ec2-user/analysis/work/scratch/tensor_co...
# 5   /home/ec2-user/analysis/work/scratch/tensor_co...
# 6   /home/ec2-user/analysis/work/scratch/tensor_co...
# 7   /home/ec2-user/analysis/work/scratch/tensor_co...
# 8   /home/ec2-user/analysis/work/scratch/tensor_co...
# 9   /work/scratch/tensor_completion/4D/structural/...
# 10  /work/scratch/tensor_completion/4D/structural/...
# 11  /work/scratch/tensor_completion/4D/structural/...
# 12  /home/ec2-user/analysis/work/scratch/tensor_co...
# 13  /home/ec2-user/analysis/work/scratch/tensor_co...
# 14  /home/ec2-user/analysis/work/scratch/tensor_co...
# 15  /home/ec2-user/analysis/work/scratch/tensor_co...
# 16  /home/ec2-user/analysis/work/scratch/tensor_co...
# 17  /home/ec2-user/analysis/work/scratch/tensor_co...
# 18  /home/ec2-user/analysis/work/scratch/tensor_co...
# 19  /home/ec2-user/analysis/work/scratch/tensor_co...
# 20  /home/ec2-user/analysis/work/scratch/tensor_co...
# 21  /home/ec2-user/analysis/work/scratch/tensor_co...
# 22  /home/ec2-user/analysis/work/scratch/tensor_co...
# 23  /home/ec2-user/analysis/work/scratch/tensor_co...
# 24  /home/ec2-user/analysis/work/scratch/tensor_co...
# 25  /home/ec2-user/analysis/work/scratch/tensor_co...
# 26  /home/ec2-user/analysis/work/scratch/tensor_co...
# 27  /home/ec2-user/analysis/work/scratch/tensor_co...
# 28  /home/ec2-user/analysis/work/scratch/tensor_co...
# 29  /home/ec2-user/analysis/work/scratch/tensor_co...
#
#                                       scan_final_path  \
# 0   /home/ec2-user/analysis/work/scratch/tensor_co...
# 1   /work/scratch/tensor_completion/4D/structural/...
# 2   /home/ec2-user/analysis/work/scratch/tensor_co...
# 3   /home/ec2-user/analysis/work/scratch/tensor_co...
# 4   /home/ec2-user/analysis/work/scratch/tensor_co...
# 5   /home/ec2-user/analysis/work/scratch/tensor_co...
# 6   /home/ec2-user/analysis/work/scratch/tensor_co...
# 7   /home/ec2-user/analysis/work/scratch/tensor_co...
# 8   /home/ec2-user/analysis/work/scratch/tensor_co...
# 9   /work/scratch/tensor_completion/4D/structural/...
# 10  /work/scratch/tensor_completion/4D/structural/...
# 11  /work/scratch/tensor_completion/4D/structural/...
# 12  /home/ec2-user/analysis/work/scratch/tensor_co...
# 13  /home/ec2-user/analysis/work/scratch/tensor_co...
# 14  /home/ec2-user/analysis/work/scratch/tensor_co...
# 15  /home/ec2-user/analysis/work/scratch/tensor_co...
# 16  /home/ec2-user/analysis/work/scratch/tensor_co...
# 17  /home/ec2-user/analysis/work/scratch/tensor_co...
# 18  /home/ec2-user/analysis/work/scratch/tensor_co...
# 19  /home/ec2-user/analysis/work/scratch/tensor_co...
# 20  /home/ec2-user/analysis/work/scratch/tensor_co...
# 21  /home/ec2-user/analysis/work/scratch/tensor_co...
# 22  /home/ec2-user/analysis/work/scratch/tensor_co...
# 23  /home/ec2-user/analysis/work/scratch/tensor_co...
# 24  /home/ec2-user/analysis/work/scratch/tensor_co...
# 25  /home/ec2-user/analysis/work/scratch/tensor_co...
# 26  /home/ec2-user/analysis/work/scratch/tensor_co...
# 27  /home/ec2-user/analysis/work/scratch/tensor_co...
# 28  /home/ec2-user/analysis/work/scratch/tensor_co...
# 29  /home/ec2-user/analysis/work/scratch/tensor_co...
#
#                                   scan_iteration_path  \
# 0   /home/ec2-user/analysis/work/scratch/tensor_co...
# 1   /work/scratch/tensor_completion/4D/structural/...
# 2   /home/ec2-user/analysis/work/scratch/tensor_co...
# 3   /home/ec2-user/analysis/work/scratch/tensor_co...
# 4   /home/ec2-user/analysis/work/scratch/tensor_co...
# 5   /home/ec2-user/analysis/work/scratch/tensor_co...
# 6   /home/ec2-user/analysis/work/scratch/tensor_co...
# 7   /home/ec2-user/analysis/work/scratch/tensor_co...
# 8   /home/ec2-user/analysis/work/scratch/tensor_co...
# 9   /work/scratch/tensor_completion/4D/structural/...
# 10  /work/scratch/tensor_completion/4D/structural/...
# 11  /work/scratch/tensor_completion/4D/structural/...
# 12  /home/ec2-user/analysis/work/scratch/tensor_co...
# 13  /home/ec2-user/analysis/work/scratch/tensor_co...
# 14  /home/ec2-user/analysis/work/scratch/tensor_co...
# 15  /home/ec2-user/analysis/work/scratch/tensor_co...
# 16  /home/ec2-user/analysis/work/scratch/tensor_co...
# 17  /home/ec2-user/analysis/work/scratch/tensor_co...
# 18  /home/ec2-user/analysis/work/scratch/tensor_co...
# 19  /home/ec2-user/analysis/work/scratch/tensor_co...
# 20  /home/ec2-user/analysis/work/scratch/tensor_co...
# 21  /home/ec2-user/analysis/work/scratch/tensor_co...
# 22  /home/ec2-user/analysis/work/scratch/tensor_co...
# 23  /home/ec2-user/analysis/work/scratch/tensor_co...
# 24  /home/ec2-user/analysis/work/scratch/tensor_co...
# 25  /home/ec2-user/analysis/work/scratch/tensor_co...
# 26  /home/ec2-user/analysis/work/scratch/tensor_co...
# 27  /home/ec2-user/analysis/work/scratch/tensor_co...
# 28  /home/ec2-user/analysis/work/scratch/tensor_co...
# 29  /home/ec2-user/analysis/work/scratch/tensor_co...
#
#                                         metadata_path spatial_mr_rate  \
# 0   /home/ec2-user/analysis/work/scratch/tensor_co...        0.015272
# 1   /work/scratch/tensor_completion/4D/structural/...        0.017454
# 2   /home/ec2-user/analysis/work/scratch/tensor_co...        0.019636
# 3   /home/ec2-user/analysis/work/scratch/tensor_co...        0.021817
# 4   /home/ec2-user/analysis/work/scratch/tensor_co...        0.023999
# 5   /home/ec2-user/analysis/work/scratch/tensor_co...        0.026181
# 6   /home/ec2-user/analysis/work/scratch/tensor_co...        0.015272
# 7   /home/ec2-user/analysis/work/scratch/tensor_co...        0.017454
# 8   /home/ec2-user/analysis/work/scratch/tensor_co...        0.019636
# 9   /work/scratch/tensor_completion/4D/structural/...        0.021817
# 10  /work/scratch/tensor_completion/4D/structural/...        0.023999
# 11  /work/scratch/tensor_completion/4D/structural/...        0.026181
# 12  /home/ec2-user/analysis/work/scratch/tensor_co...        0.015272
# 13  /home/ec2-user/analysis/work/scratch/tensor_co...        0.017454
# 14  /home/ec2-user/analysis/work/scratch/tensor_co...        0.019636
# 15  /home/ec2-user/analysis/work/scratch/tensor_co...        0.021817
# 16  /home/ec2-user/analysis/work/scratch/tensor_co...        0.023999
# 17  /home/ec2-user/analysis/work/scratch/tensor_co...        0.026181
# 18  /home/ec2-user/analysis/work/scratch/tensor_co...        0.015272
# 19  /home/ec2-user/analysis/work/scratch/tensor_co...        0.017454
# 20  /home/ec2-user/analysis/work/scratch/tensor_co...        0.019636
# 21  /home/ec2-user/analysis/work/scratch/tensor_co...        0.021817
# 22  /home/ec2-user/analysis/work/scratch/tensor_co...        0.023999
# 23  /home/ec2-user/analysis/work/scratch/tensor_co...        0.026181
# 24  /home/ec2-user/analysis/work/scratch/tensor_co...        0.015272
# 25  /home/ec2-user/analysis/work/scratch/tensor_co...        0.017454
# 26  /home/ec2-user/analysis/work/scratch/tensor_co...        0.019636
# 27  /home/ec2-user/analysis/work/scratch/tensor_co...        0.021817
# 28  /home/ec2-user/analysis/work/scratch/tensor_co...        0.023999
# 29  /home/ec2-user/analysis/work/scratch/tensor_co...        0.026181
#
#     spatial_mr_rate_perc  spatiotemporal_mr_rate  spatiotemporal_mr_rate_perc
# 0                   1.53                0.000742                        0.074
# 1                   1.75                0.000848                        0.085
# 2                   1.96                0.000954                        0.095
# 3                   2.18                0.001061                        0.106
# 4                   2.40                0.001167                        0.117
# 5                   2.62                0.001273                        0.127
# 6                   1.53                0.001485                        0.148
# 7                   1.75                0.001697                        0.170
# 8                   1.96                0.001909                        0.191
# 9                   2.18                0.002121                        0.212
# 10                  2.40                0.002333                        0.233
# 11                  2.62                0.002545                        0.255
# 12                  1.53                0.002227                        0.223
# 13                  1.75                0.002545                        0.255
# 14                  1.96                0.002864                        0.286
# 15                  2.18                0.003182                        0.318
# 16                  2.40                0.003500                        0.350
# 17                  2.62                0.003818                        0.382
# 18                  1.53                0.002970                        0.297
# 19                  1.75                0.003394                        0.339
# 20                  1.96                0.003818                        0.382
# 21                  2.18                0.004242                        0.424
# 22                  2.40                0.004666                        0.467
# 23                  2.62                0.005091                        0.509
# 24                  1.53                0.003818                        0.382
# 25                  1.75                0.004363                        0.436
# 26                  1.96                0.004909                        0.491
# 27                  2.18                0.005454                        0.545
# 28                  2.40                0.006000                        0.600
# 29                  2.62                0.006545                        0.655
#
# [30 rows x 21 columns]

# %%
xlist = pd.Series(subset4D['mr']).values
ylist = pd.Series(subset4D['spatial_mr_rate_perc']).values

# %%
type(ylist)
# Out:
# numpy.ndarray

# %%
X, Y = np.meshgrid(xlist, ylist)

# %%
def f(dataset, x, y):
    row1 = dataset.loc[dataset['mr'] == x]
    row2 = row1.loc[dataset['spatial_mr_rate_perc'] == y]
    result = row2['tcs_cost']
    return result

# %%
f(subset4D, 5,1.53)
# Out:
# 0    0.002607
# Name: tcs_cost, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-07a6cf29e848> in <module>()
# ----> 1 row1 = dataset.loc[dataset['mr'] == x]
#       2 row2 = row1.loc[dataset['spatial_mr_rate_perc'] == y]
#       3 Z = row2['tcs_cost']
#
# NameError: name 'dataset' is not defined

# %%
xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X ** 2 + Y ** 2 )
plt.figure()
levels = [0.0, 0.2, 0.5, 0.9, 1.5, 2.5, 3.5]
contour = plt.contour(X, Y, Z, levels, colors='k')
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=12)
contour_filled = plt.contourf(X, Y, Z, levels)
plt.colorbar(contour_filled)
plt.title('Plot from level list')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.show()

# %%
X.shape
# Out:
# (30, 30)

# %%
Z = np.zeros_like(X)

# %%
Z.shape
# Out:
# (30, 30)

# %%
rowctr = 0
colctr = 0
for x1 in xlist:
    for y1 in ylist:
        print f(subset4D, x1, y1)
        Z[rowctr, colctr] = f(subset4D, x1, y1)
        colctr = colctr + 1
    rowctr  = rowctr + 1
# Out:
# 0    0.002607
# Name: tcs_cost, dtype: float64
# 1    0.002822
# Name: tcs_cost, dtype: float64
# 2    0.002803
# Name: tcs_cost, dtype: float64
# 3    0.003107
# Name: tcs_cost, dtype: float64
# 4    0.003402
# Name: tcs_cost, dtype: float64
# 5    0.00353
# Name: tcs_cost, dtype: float64
# 0    0.002607
# Name: tcs_cost, dtype: float64
# 1    0.002822
# Name: tcs_cost, dtype: float64
# 2    0.002803
# Name: tcs_cost, dtype: float64
# 3    0.003107
# Name: tcs_cost, dtype: float64
# 4    0.003402
# Name: tcs_cost, dtype: float64
# 5    0.00353
# Name: tcs_cost, dtype: float64
# 0    0.002607
# Name: tcs_cost, dtype: float64
# 1    0.002822
# Name: tcs_cost, dtype: float64
# 2    0.002803
# Name: tcs_cost, dtype: float64
# 3    0.003107
# Name: tcs_cost, dtype: float64
# 4    0.003402
# Name: tcs_cost, dtype: float64
# 5    0.00353
# Name: tcs_cost, dtype: float64
# 0    0.002607
# Name: tcs_cost, dtype: float64
# 1    0.002822
# Name: tcs_cost, dtype: float64
# 2    0.002803
# Name: tcs_cost, dtype: float64
# 3    0.003107
# Name: tcs_cost, dtype: float64
# 4    0.003402
# Name: tcs_cost, dtype: float64
# 5    0.00353
# Name: tcs_cost, dtype: float64
# 0    0.002607
# Name: tcs_cost, dtype: float64
# 1    0.002822
# Name: tcs_cost, dtype: float64
# 2    0.002803
# Name: tcs_cost, dtype: float64
# 3    0.003107
# Name: tcs_cost, dtype: float64
# 4    0.003402
# Name: tcs_cost, dtype: float64
# 5    0.00353
# Name: tcs_cost, dtype: float64
# 0    0.002607
# Name: tcs_cost, dtype: float64
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-12eb1af9b80e> in <module>()
#       4     for y1 in ylist:
#       5         print f(subset4D, x1, y1)
# ----> 6         Z[rowctr, colctr] = f(subset4D, x1, y1)
#       7         colctr = colctr + 1
#       8     rowctr  = rowctr + 1
#
# IndexError: index 30 is out of bounds for axis 1 with size 30

# %%
for x1 in xlist:
    print x1
# Out:
# 5
# 5
# 5
# 5
# 5
# 5
# 10
# 10
# 10
# 10
# 10
# 10
# 15
# 15
# 15
# 15
# 15
# 15
# 20
# 20
# 20
# 20
# 20
# 20
# 25
# 25
# 25
# 25
# 25
# 25
