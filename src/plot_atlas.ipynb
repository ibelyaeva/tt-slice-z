# %%
# %matplotlib inline

# %% [markdown]
# Basic Atlas plotting
# =======================
#
# Plot the regions of a reference atlas (here the Harvard-Oxford atlas).

# %% [markdown]
# Retrieving the atlas data
# -------------------------

# %%
from nilearn import datasets

dataset = datasets.fetch_atlas_harvard_oxford('cort-maxprob-thr25-2mm')
atlas_filename = dataset.maps

print('Atlas ROIs are located at: %s' % atlas_filename)
# Out:
# Dataset created in /Users/cn101458/nilearn_data/fsl
#
# Downloading data from http://www.nitrc.org/frs/download.php/7700/HarvardOxford.tgz ...
# Downloaded 15761498 of 15761498 bytes (100.0%,    0.0s remaining) ...done. (6 seconds, 0 min)
# Extracting data from /Users/cn101458/nilearn_data/fsl/5c1bec1e672ec3a7f188115b28f647eb/HarvardOxford.tgz...
# Atlas ROIs are located at: /Users/cn101458/nilearn_data/fsl/data/atlases/HarvardOxford/HarvardOxford-cort-maxprob-thr25-2mm.nii.gz
# .. done.

# %% [markdown]
# Visualizing the Harvard-Oxford atlas
# ------------------------------------

# %%
plotting.find_parcellation_cut_coords()
